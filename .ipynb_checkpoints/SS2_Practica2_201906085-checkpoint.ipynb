# %%
import pandas as pd


# Leer el archivo CSV
datos = pd.read_csv("datos.csv", names=[
    "Course Title",
    "Rating",
    "Level",
    "Duration",
    "Schedule",
    "Review",
    "What you will learn",
    "Skill gain",
    "Modules",
    "Instructor",
    "Offered By",
    "Keyword",
    "Course Url"
])

# Función para eliminar corchetes y comillas simples
def limpiar_datos(valor):
    if isinstance(valor, str):
        valor = valor.replace("[", "").replace("]", "").replace("'", "").replace("\"","")
    return valor

# Aplicar la función a las columnas especificadas
columnas_a_limpiar = ["What you will learn", "Skill gain", "Modules", "Instructor", "Offered By", "Keyword"]
datos[columnas_a_limpiar] = datos[columnas_a_limpiar].map(limpiar_datos)

# Mostrar el DataFrame limpio
datos
# Out:
#                                            Course Title  Rating  \
# 0                                          Course Title  Rating
# 1                             Fashion as Design悖论：思维的魔方     4.8
# 2                                Modern American Poetry     4.4
# 3                             Pixel Art for Video Games     4.5
# 4       Distribución digital de la música independiente     NaN
# ...                                                 ...     ...
# 9591                                   Power Onboarding     4.1
# 9592     Implementing Parent Feedback with Google Forms     4.9
# 9593                        "Making" Progress Teach-Out     4.2
# 9594  Use Microsoft PowerPoint to Create a Visual Sc...     4.5
# 9595  Créer du contenu pour les réseaux sociaux avec...     NaN
#
#                Level                      Duration           Schedule  \
# 0              Level                      Duration           Schedule
# 1     Beginner level      20 hours (approximately)  Flexible schedule
# 2     Beginner level  Approx. 34 hours to complete  Flexible schedule
# 3     Beginner level       9 hours (approximately)  Flexible schedule
# 4     Beginner level   Approx. 8 hours to complete  Flexible schedule
# ...              ...                           ...                ...
# 9591  Beginner level   Approx. 7 hours to complete  Flexible schedule
# 9592  Beginner level                           NaN                NaN
# 9593  Beginner level   Approx. 5 hours to complete  Flexible schedule
# 9594  Beginner level                        1 hour                NaN
# 9595  Beginner level                           NaN                NaN
#
#              Review                                What you will learn  \
# 0            Review                                What you will learn
# 1     2,813 reviews                                                NaN
# 2       100 reviews                                                NaN
# 3       227 reviews                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 9591     36 reviews                                                NaN
# 9592     77 reviews  Creating engaging parent surveys using Google ...
# 9593     10 reviews                                                NaN
# 9594     11 reviews  Learn about choice boards and their use within...
# 9595            NaN  Vous découvrirez les fonctionnalités de Prezi ...
#
#                                              Skill gain  \
# 0                                            Skill gain
# 1                 Art History, Art, History, Creativity
# 2
# 3
# 4
# ...                                                 ...
# 9591
# 9592  Education, online tools, engagement, elementar...
# 9593
# 9594  Teaching tools, elementary teaching, engaging ...
# 9595  Social Media Marketing, Social Media, Content ...
#
#                                                 Modules  \
# 0                                               Modules
# 1     Introduction, Heroes, Silhouettes, Coutures, L...
# 2     Orientation, Module 1, Module 2, Module 3, Mod...
# 3     Week 1: Introduction to Pixel Art, Week 2: Pix...
# 4                Semana 1, Semana 2, Semana 3, Semana 4
# ...                                                 ...
# 9591  Week 1 - Get Ready, Session 2 - Get Set, Sessi...
# 9592                                 Learn step-by-step
# 9593                                     Week 1, WEEK 2
# 9594                                 Learn step-by-step
# 9595                                 Learn step-by-step
#
#                                              Instructor  \
# 0                                            Instructor
# 1     Anna Burckhardt, Paola Antonelli, Michelle Mil...
# 2                                           Cary Nelson
# 3                      Andrew Dennis, Ricardo Guimaraes
# 4                             Eduardo de la Vara Brown.
# ...                                                 ...
# 9591                                   William J. White
# 9592                                     Rachel Lindsay
# 9593                                     Pablo Palomino
# 9594                                     Rachel Lindsay
# 9595                                      Sara Nefzaoui
#
#                                       Offered By              Keyword  \
# 0                                     Offered By              Keyword
# 1                       The Museum of Modern Art  Arts and Humanities
# 2     University of Illinois at Urbana-Champaign  Arts and Humanities
# 3                      Michigan State University  Arts and Humanities
# 4                           SAE Institute México  Arts and Humanities
# ...                                          ...                  ...
# 9591                     Northwestern University      Social Sciences
# 9592                    Coursera Project Network      Social Sciences
# 9593                            Emory University      Social Sciences
# 9594                    Coursera Project Network      Social Sciences
# 9595                    Coursera Project Network      Social Sciences
#
#                                              Course Url
# 0                                            Course Url
# 1         https://www.coursera.org/learn/fashion-design
# 2     https://www.coursera.org/learn/modern-american...
# 3     https://www.coursera.org/learn/pixel-art-video...
# 4     https://www.coursera.org/learn/distribucion-di...
# ...                                                 ...
# 9591    https://www.coursera.org/learn/power-onboarding
# 9592  https://www.coursera.org/projects/education-fe...
# 9593      https://www.coursera.org/learn/makingprogress
# 9594  https://www.coursera.org/projects/use-microsof...
# 9595  https://www.coursera.org/projects/creer-conten...
#
# [9596 rows x 13 columns]
