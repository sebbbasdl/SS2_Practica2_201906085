# %% [markdown]
# #### Sebastian Alejandro de Leon Tenaz - 201906085
#
# # Practica 2 - Análisis de datos con Python

# %%
import pandas as pd

# Leer el archivo CSV
datos = pd.read_csv("datos.csv", names=[
    "Course Title",
    "Rating",
    "Level",
    "Duration",
    "Schedule",
    "Review",
    "What you will learn",
    "Skill gain",
    "Modules",
    "Instructor",
    "Offered By",
    "Keyword",
    "Course Url"
])

# Función para eliminar corchetes y comillas simples
def limpiar_datos(valor):
    if isinstance(valor, str):
        valor = valor.replace("[", "").replace("]", "").replace("'", "").replace("\"","")
    return valor

# Aplicar la función a las columnas especificadas
columnas_a_limpiar = ["What you will learn", "Skill gain", "Modules", "Instructor", "Offered By", "Keyword"]
datos[columnas_a_limpiar] = datos[columnas_a_limpiar].map(limpiar_datos)

# Convertir la columna 'Rating' a tipo float, manejar errores
def convertir_a_float(valor):
    try:
        return float(valor)
    except ValueError:
        return None

datos['Rating'] = datos['Rating'].map(convertir_a_float)

# Eliminar filas con valor NaN en la columna 'Rating'
datos = datos.dropna(subset=['Rating'])

# Calcular el promedio de calificaciones para cada curso
promedio_calificaciones = datos.groupby('Course Title')['Rating'].mean()

# Mostrar todos los promedios de calificaciones
#pd.set_option('display.max_rows', None)
print("Promedio de calificaciones por curso:", round(promedio_calificaciones,2))



# Restaurar la configuración de visualización
pd.reset_option('display.max_rows')

# Cursos con la calificación más alta
max_rating = promedio_calificaciones.max()
cursos_max_rating = promedio_calificaciones[promedio_calificaciones == max_rating].index.tolist()
print("-------------Cursos con mayor rating:-------------\n\n", cursos_max_rating, "- Rating:", max_rating)
print()

# Cursos con la calificación más baja
min_rating = promedio_calificaciones.min()
cursos_min_rating = promedio_calificaciones[promedio_calificaciones == min_rating].index.tolist()
count=0
cadena_curso_min = ""
for cursos_min in cursos_min_rating:
    count= count +1 
    cadena_curso_min += str(count) + ". " + cursos_min +"\n"
    
print("-------------Cursos con menor rating:-------------\n\n", cadena_curso_min, "- Rating:", min_rating)
print()


# Eliminar cursos duplicados
datos_cursos = datos.drop_duplicates(subset=['Course Title'])

# Calcular el porcentaje de cursos con horario flexible
total_cursos = len(datos_cursos)
print(total_cursos)
cursos_horario_flexible = datos[datos['Schedule'] == 'Flexible schedule']['Course Title'].nunique()
porcentaje_horario_flexible = (cursos_horario_flexible / total_cursos) * 100
porcentaje_horario_flexible = round(porcentaje_horario_flexible, 2)

print("Porcentaje de cursos con horario flexible:", porcentaje_horario_flexible, "%")
# Out:
# Promedio de calificaciones por curso: Course Title
#  Assisting Public Sector Decision Makers With Policy Analysis                                                          4.8
#  Atención prehospitalaria del ictus agudo y selección de pacientes para tratamiento endovascular con la escala RACE    4.9
#  Build a social media presence for your business using Canva                                                           4.7
#  Comercio, Inmigración y Tipos de Cambio en un Mundo Globalizado                                                       4.9
#  FPGA computing systems: Background knowledge and introductory materials                                               4.6
#                                                                                                                       ...
# 頑想學概率：機率二 (Probability (2))                                                                                            4.8
# 食品安全與毒理 (Food Safety & Toxicology)                                                                                     4.8
# 食品安全與風險分析（Food Safety＆Risk Analysis）                                                                                   4.9
# 高效协作                                                                                                                   4.0
# 파이썬 단기집중과정                                                                                                             4.7
# Name: Rating, Length: 5145, dtype: float64
# -------------Cursos con mayor rating:-------------
#
#  [' التنسيق في مايكروسوفت إكسل | Formatting in MS Excel ', ' التوازن بين القدرات والتوقعات في بناء الذات', 'Activity Design with PhET Simulations for STEM Education', 'Anatomy & Physiology: Support & Movement', 'Back-end Application Development Capstone Project', 'Business Problem Solving Specialization', 'C Programming for Everybody Specialization', 'Certified Business Analysis Professional™ (CBAP®) Specialization', 'Circuitos con SPICE: Fundamentos de los circuitos eléctricos', 'Claves para la igualdad de género Specialization', 'Compreendendo o Zika e doenças emergentes', 'Compromiso del paciente: resultados clínicos satisfactorios Specialization', 'Cyber Security – Technology and Governance Specialization', 'Data Analytics in Sports Law and Management Specialization', 'Desenvolvendo sua musicalidade', 'Digital Media for Health Outcomes, English', 'Diseño de Actividades con PhET para la Educación STEM', 'Diversity, Equity, and Inclusion for Organizational Leaders Specialization', 'El Holocausto: el abismo de la humanidad', 'Engineering of Structures: Response of Structures', 'Escola 4.0 Educação e Cultura Maker no Contexto da Nova BNCC', "Exploring Beethoven's Piano Sonatas Part 5", 'Exploring Beethoven’s Piano Sonatas Part 2', 'Generative AI for Software Developers Specialization', 'Global Health Challenges and Governance Specialization', 'Google IT 지원 수료증 이수 과정 Professional Certificate', 'Google Slides en Español', 'Introduction to Systems Engineering Specialization', 'Keamanan IT: Pertahanan terhadap Kejahatan Digital', 'Keller Williams Real Estate Agent Professional Certificate', 'La salud vegetal. Plagas y enfermedades en plantas', 'Linux: Archiving and Compression for DevOps (tar/gzip)', 'Manajemen Proyek Google Professional Certificate', 'Medical Terminology II', 'Musician’s Professional Toolbox: Your Portfolio Career Specialization', 'Natural Disaster and Climate Change Risk Assessment Specialization', 'Networking Fundamentals', 'O Músico Contemporâneo Specialization', 'Practice Exam for Certified Scrum Master (CSM) Certification', 'Principles of Leadership: Leading Technical Teams Specialization', 'Programa especializado en circuitos eléctricos con SPICE Specialization', 'Project Management Capstone', 'Question Reality! Science, philosophy, a search for meaning Specialization', 'Rapid Prototyping and Tooling Specialization', 'Ready to Roll – The Video Production Process', 'Recuperación Optimizada en Cirugía Colorrectal', 'Road to the CISO – Culminating Project Course', 'Scrum Master Capstone', 'Scrum Master Specialization', 'Secure Coding in Laravel Specialization', 'Sistemas difusos', 'Songwriting: Writing the Music', 'Tecnologías para la Innovación Educativa', 'Uncommon Sense Teaching Specialization', 'Uncommon Sense Teaching: Teaching Online', 'Western Religions & Ecology', 'الطاقة الإيجابية | Positive Energy', '生物学概念与途径', '电磁学下——恒磁场与时变电磁场', '莊子─人情 (Zhuangzi─Between People)', '賽局與產業競爭策略 (Game Theory and Business Strategy)'] - Rating: 5.0
#
# -------------Cursos con menor rating:-------------
#
#  1. Build a computer vision app with Azure Cognitive Services
# 2. Build automated speech systems with Azure Cognitive Services
# 3. Excel for Beginners: Beginner Functions
#  - Rating: 1.5
#
# 5145
# Porcentaje de cursos con horario flexible: 94.11 %

# %%
import matplotlib.pyplot as plt

print(len(datos_cursos))
# Contar el número de cursos en cada nivel de dificultad
cursos_por_nivel = datos_cursos['Level'].value_counts()
print(cursos_por_nivel)

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
cursos_por_nivel.plot(kind='bar', color='skyblue')
plt.title('Número de cursos por nivel de dificultad')
plt.xlabel('Nivel de dificultad')
plt.ylabel('Número de cursos')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# 3
